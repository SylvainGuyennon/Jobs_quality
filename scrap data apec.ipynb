# %%
import pandas as pd
import requests
import time

#on check le nombre max d'annonces

url = 'https://www.apec.fr/cms/webservices/rechercheOffre'
myjson = {"lieux":[],"fonctions":[],
          "statutPoste":[],
          "typesContrat":[],"typesConvention":[],
          "niveauxExperience":["101881"],
          "idsEtablissement":[],"secteursActivite":[],
          "idNomZonesDeplacement":[],
          "positionNumbersExcluded":[],
          "typeClient":"CADRE","sorts":[{"type":"SCORE","direction":"DESCENDING"}],
          "pagination":{"range":20,"startIndex":20},"activeFiltre":True,
          "pointGeolocDeReference":{"distance":0},
          "motsCles":"data analyst"}
x = requests.post(url, json = myjson)
y = x.text
liste_totale =[]

nb_job_total = int(y[-4:-1])
nb_job_total

for i in range((nb_job_total//100)+1):
    myjson_total = {"lieux":[],
                "fonctions":[],
                "statutPoste":[],
                "typesContrat":[],
                "typesConvention":[],
                "niveauxExperience":["101881"],
                "idsEtablissement":[],
                "secteursActivite":[],
                "idNomZonesDeplacement":[],
                "positionNumbersExcluded":[],
                "typeClient":"CADRE","sorts":[{"type":"SCORE","direction":"DESCENDING"}],
                "pagination":{"range":100,"startIndex":i*100},"activeFiltre":True,
                "pointGeolocDeReference":{"distance":0},"motsCles":"data analyst"}
    x = requests.post(url, json = myjson_total)
    split = x.headers["X-Search-Results"].split()
    liste_totale += split
    

df = pd.DataFrame(columns =['intitule','nomCompteEtablissement','idNomTypeContrat','idNomNiveauExperience','texteHtmlProfil','texteHtmlEntreprise','texteHtml','salaireTexte'])
liste_lien =[]


for i in liste_totale:
    data_offre = "https://www.apec.fr/cms/webservices/offre/public?numeroOffre="+i
    liste_lien.append(data_offre)

for i in liste_lien:
    data = requests.get(i,).json()
    item_offre=[]
    time.sleep(0.5)
    print("tick")
    for j in ['intitule','nomCompteEtablissement','idNomTypeContrat','idNomNiveauExperience','texteHtmlProfil','texteHtmlEntreprise','texteHtml','salaireTexte']:
        try:
            item_offre.append(data[j])
        except KeyError:
            item_offre.append("None")
        
    df.loc[len(df)] = item_offre
# Out:
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick
# tick

# %%
df
# Out:
#                                               intitule  \
# 0                                     Data Analyst F/H
# 1                                     Data Analyst F/H
# 2                                     Data Analyst F/H
# 3                                     Data Analyst F/H
# 4                                     Data analyst F/H
# ..                                                 ...
# 211                  Analyste Données et Reporting F/H
# 212  Analyste Bi Senior - Consultant Power Bi - Qli...
# 213        Responsable service client - Prévoyance F/H
# 214                        Chargé de planification F/H
# 215  CHARGE DES STATISTIQUES ET PERFORMANCE - TOURS...
#
#                nomCompteEtablissement idNomTypeContrat idNomNiveauExperience  \
# 0                              FED IT           101888                597152
# 1                             KERISTO           101888                597151
# 2                             KERISTO           101888                597151
# 3                               UNLCK           101888                597152
# 4                     LV TECHNOLOGIES           101888                597152
# ..                                ...              ...                   ...
# 211                       SudOuestJob           101888                200269
# 212                            Cadreo           101888                200269
# 213         GIE DE PREVOYANCE SOCIALE           101888                597152
# 214  ADMIRAL INTERMEDIARY SERVICES SA           101888                200269
# 215                       DOMITYS SAS           101888                597152
#
#                                        texteHtmlProfil  \
# 0    <p>Issu d'une formation relative à l'analyse d...
# 1    <p>Vous êtes de formation supérieure (BAC+5) e...
# 2    <p>Vous êtes de formation supérieure (BAC+5) e...
# 3    <p><strong>Profil</strong></p><p>Vous êtes dip...
# 4    <p>-       De formation Bac +2/5 BTS ou DUT, u...
# ..                                                 ...
# 211  De formation Bac +3 à Bac +5 dans l'analyse de...
# 212  - De formation Bac +5 (ingénieur ou équivalent...
# 213  <p>Vous possédez une expérience significative ...
# 214  <p>Chez L'olivier, on est bien sûr intéressé p...
# 215  <p> </p><p><br />De formation statisticienne o...
#
#                                    texteHtmlEntreprise  \
# 0    <p>Camille Bernard, consultante chez Fed IT, c...
# 1    <p>Keristo est une jeune société de conseil av...
# 2    <p>Keristo est une jeune société de conseil av...
# 3    <p>Acteur indépendant du recrutement tech, UNL...
# 4    <p>Nous recrutons pour le compte de notre clie...
# ..                                                 ...
# 211  Lectra développe des solutions premium qui don...
# 212  Alliance Automotive Group France est un acteur...
# 213  <p>Fondé en 1970, le GIEPS (GIE de Prévoyance ...
# 214  <p>Vous nous connaissez peut-être déjà, mais s...
# 215  <p> </p><p><br />Tellement plus à vivre quand ...
#
#                                              texteHtml            salaireTexte
# 0    <p><strong>A ce titre, vos missions sont les s...  38 - 45 k€ brut annuel
# 1    <p>En tant que Data Analyst, vos missions sont...              A négocier
# 2    <p>En tant que Data Analyst, vos missions sont...              A négocier
# 3    <p><strong>Contexte</strong></p><p>Vous êtes D...  40 - 50 k€ brut annuel
# 4    <p>Vous serez rattaché/e au chief data officer...  40 - 42 k€ brut annuel
# ..                                                 ...                     ...
# 211  Entreprise transnationale de 1 700 collaborate...              A négocier
# 212  Acteur majeur de la Distribution de pièces de ...              A négocier
# 213  <p>Rattaché(e) au Responsable Opérationnel Pré...  40 - 43 k€ brut annuel
# 214  <p>Votre mission si vous l'acceptez :<br /><br...              A négocier
# 215  <p> </p><p><br />Rattaché à la Directrice Mark...  30 - 33 k€ brut annuel
#
# [216 rows x 8 columns]

# %%
df.to_csv("data_apec.csv")
